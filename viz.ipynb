# %%
import numpy as np
import matplotlib.pyplot as plt

import glob
import pandas as pd
import seaborn as sns

# %%
df = pd.DataFrame(np.loadtxt('sim_data/time_results.txt'), columns=['B', 'Strip size','ID', 'Time'])

# %%
sns.lineplot(x = 'Strip size',y='Time',hue='B',data=df)

# %%
f
# Out:
# []

# %%
plt.imshow(np.loadtxt(f[-3], delimiter= ',')[:,2:].reshape((xD,yD,2))[:,:,1])
plt.colorbar()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-210-8cd0c655e4f7> in <module>
# ----> 1 plt.imshow(np.loadtxt(f[-3], delimiter= ',')[:,2:].reshape((xD,yD,2))[:,:,1])
#       2 plt.colorbar()
#
# IndexError: list index out of range

# %%
plt.imshow(np.loadtxt('prof_T2098_2021-04-08-00-41-17.txt', delimiter= ',')[:,2:].reshape((xD,yD,2))[:,:,1])
plt.colorbar()
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-193-a867aafff062> in <module>
# ----> 1 plt.imshow(np.loadtxt('prof_T2098_2021-04-08-00-41-17.txt', delimiter= ',')[:,2:].reshape((xD,yD,2))[:,:,1])
#       2 plt.colorbar()
#
# ~/anaconda3/lib/python3.8/site-packages/numpy/lib/npyio.py in loadtxt(fname, dtype, comments, delimiter, converters, skiprows, usecols, unpack, ndmin, encoding, max_rows)
#     979             fname = os_fspath(fname)
#     980         if _is_string_like(fname):
# --> 981             fh = np.lib._datasource.open(fname, 'rt', encoding=encoding)
#     982             fencoding = getattr(fh, 'encoding', 'latin1')
#     983             fh = iter(fh)
#
# ~/anaconda3/lib/python3.8/site-packages/numpy/lib/_datasource.py in open(path, mode, destpath, encoding, newline)
#     267
#     268     ds = DataSource(destpath)
# ...

# %%
dt
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-56-36673dcb6ee0> in <module>
# ----> 1 dt
#
# NameError: name 'dt' is not defined

# %%
f = glob.glob('log*')

# %%
np.loadtxt(f[1],delimiter= ", ")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-60-8871c9a96262> in <module>
# ----> 1 np.loadtxt(f[1],delimiter= ", ")
#
# ~/anaconda3/lib/python3.8/site-packages/numpy/lib/npyio.py in loadtxt(fname, dtype, comments, delimiter, converters, skiprows, usecols, unpack, ndmin, encoding, max_rows)
#    1157         # converting the data
#    1158         X = None
# -> 1159         for x in read_data(_loadtxt_chunksize):
#    1160             if X is None:
#    1161                 X = np.array(x, dtype)
#
# ~/anaconda3/lib/python3.8/site-packages/numpy/lib/npyio.py in read_data(chunk_size)
#    1085
#    1086             # Convert each value according to its column and store
# -> 1087             items = [conv(val) for (conv, val) in zip(converters, vals)]
#    1088
#    1089             # Then pack it according to the dtype's nesting
#
# ...
